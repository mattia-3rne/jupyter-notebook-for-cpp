# %% [markdown]
# # Template

# %% [markdown]
# ## Notebook Setup

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))
from cpp_runner import load_cpp_magic

load_cpp_magic()
print("Bereit: Nutze %%cpp in Code-Zellen.")
# Out:
# Bereit: Nutze %%cpp in Code-Zellen.

# %% [markdown]
# ## Code Beispiel

# %%
# %%cpp
# #include <iostream>
#
# int main() {
#     std::cout << "Hello, World!" << std::endl;
#     return 0;
# }
# Out:
# Hello, World!
